# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthaduvvuri/ML---practise-projects-/blob/main/House_Price_Prediction_using_Support_Vector_Regression_(SVR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing() #fetching the data

# %%
import pandas as pd #importing pandas library

# %%
df = pd.DataFrame(data.data, columns=data.feature_names) #creating a dataframe

# %%
df['target'] = data.target

# %%
import missingno
missingno.matrix(df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[data.feature_names] = scaler.fit_transform(df[data.feature_names])

# %%
from sklearn.svm import SVR
model = SVR()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
X_train , X_test, y_train, y_test = train_test_split(df.drop('target', axis=1), df['target'], test_size=0.2, random_state=42)

# %%
X_train
y_train
# Out:
# 14196    1.030
# 8267     3.821
# 17445    1.726
# 14265    0.934
# 2271     0.965
#          ...
# 11284    2.292
# 11964    0.978
# 5390     2.221
# 860      2.835
# 15795    3.250
# Name: target, Length: 16512, dtype: float64

# %%
model.fit(X_train, y_train) #training
# Out:
# SVR()

# %%
mse = mean_squared_error(y_test, model.predict(X_test))
print(mse)
# Out:
# 0.3551984619989418

# %%
mae = mean_absolute_error(y_test, model.predict(X_test))
print(mae)
# Out:
# 0.3977630963437868
